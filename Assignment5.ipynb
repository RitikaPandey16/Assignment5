# %%
'''
Q1.who developed python programming language?
Ans. Guido Van Rossum
Q2.which type of programming does pyhton support?
Ans.Python supports multiple programming paradigms, making it a versatile language. These include:
    Imperative Programming 
    Object-Oriented Programming (OOP)
    Functional Programming
    Procedural Programming 
    Declarative Programming 
    Concurrent Programming 
Q3.Is pyhton case sensitive when dealing with identifiers?
Ans.yes
Q4.What is the correct extension of the python file?
Ans. .py
Q5.Is pyhton code compiled or interpreted?
Ans. Interpreted
Q6.Name a few blocks of code used to define in python language?
Ans.if condition:
    # Code block for the 'if' condition
    print("Condition is True")
    else:
    # Code block for the 'else' condition
    print("Condition is False")
Q7.State a character used to give single line comments in python?
Ans. #
Q8.Mention function which can help us to find the version of python that we are currently working on?
Ans.import sys
    print(sys.version)
Q9.Python supports the creation of anonymous functions at runtime,using a construct called.........?
Ans.lambda
Q10.What does pip stands for in python?
Ans."Pip Installs Packages" or "Pip Installs Python"
Q11.Mention a few built in functions in python?
Ans. print(),max(),min(),sum(),len() and many more
Q12.What is the maximum possible length of an identifier in pyhton?
Ans.There is no fixed maximum length for an identifier
Q13.What are the benefits of using python?
Ans:The benfits of using python are:
    1.Simple syntax
    2.Easy to understand
    3.Interpreted language
    4.Dynamically typed 
    and many more
Q14.How is memory managed in python?
Ans.Memory management in Python is handled automatically by Python’s built-in garbage collector,
but it also relies on certain techniques such as reference counting and memory pools to efficiently manage memory.
Q15.How to install python on windows and set path variables?
Ans.To install Python on Windows and set up the necessary environment variables, follow these steps:

        Step 1: Download Python Installer
        Go to the official Python website: https://www.python.org/downloads/.
        Download the latest version of Python for Windows (e.g., Python 3.x.x).
        Make sure you download the installer that matches your system architecture (32-bit or 64-bit).
        Step 2: Run the Installer
        Once the installer is downloaded, open it to start the installation process.
        
        Important: On the first screen, check the box that says "Add Python to PATH". This will automatically set up the necessary environment variables for you.
        
        Click "Install Now". This will install Python, along with pip (the package manager) and IDLE (the integrated development environment).
        
        If you missed checking the "Add Python to PATH" box, you can select "Customize installation" and ensure that the box is checked during the installation process.
        Step 3: Set Environment Variables Manually (if needed)
        If you didn't check the "Add Python to PATH" box during installation, you will need to set the environment variables manually:
        
        Find the Python Installation Path:
        
        Typically, Python will be installed in a folder like:
        C:\Users\<YourUsername>\AppData\Local\Programs\Python\Python3x\
        Set the PATH variable:
        
        Right-click on the Start menu and select System.
        Click on Advanced system settings on the left side.
        In the System Properties window, click on the Environment Variables button.
        Under the System variables section, find the Path variable, select it, and click Edit.
        In the Edit Environment Variable window, click New, then paste the path to the Python installation directory (e.g., C:\Users\<YourUsername>\AppData\Local\Programs\Python\Python3x\).
        Additionally, add the Scripts directory path, which is usually located in the same folder (e.g., C:\Users\<YourUsername>\AppData\Local\Programs\Python\Python3x\Scripts\).
        Confirm the Changes:
        
        Click OK in all the open windows to save your changes.
        Step 4: Verify the Installation
        After setting the path, verify that Python is installed correctly:
        
        Open Command Prompt (type cmd in the Start menu search and press Enter).
        
        Type the following command to check the Python version:
        
        bash
        Copy code
        python --version
        You should see the Python version number printed (e.g., Python 3.x.x).
        
        Check if pip (Python package manager) is installed by typing:
        
        bash
        Copy code
        pip --version
        This should return the version of pip if it’s installed correctly.

        Step 5: Testing Python
        To ensure Python works properly, you can run the interactive Python shell:
